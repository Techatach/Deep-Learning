# %%
### การติดตั้ง tensorflow และ keras ใน Anaconda ให้ติดตั้ง Python 3.6.8 (อย่าให้ version เกินนี้ เพื่อรองรับ tensorflow)
### เสร็จแล้วเปิด Anaconda Prompt C:\Users\Techatach> (ชื่อ Techatach แต่ละคนไม่เหมือนกัน)แล้วพิมพ์คำสั่ง ดังนี้
#conda info --envs
#conda update --all
#conda update conda
########## Jeff Heaton ##########
#conda create --name tensorflow python=3.6
#conda activate tensorflow ## หรือ activate tensorflow
### จะเปลี่ยนเป็น (tensorflow) C:\Users\Techatach>
#################################
#conda install jupyter
#conda install scipy
#pip install --upgrade sklearn
#pip install --upgrade pandas
#pip install --upgrade pandas-datareader
#pip install --upgrade matplotlib
#pip install --upgrade pillow
#pip install --upgrade requests
#pip install --upgrade h5py
#pip install --upgrade psutil
#pip install --upgrade tensorflow==1.12.0
#pip install --upgrade keras==2.2.4

### พิมพ์ python เพื่อนำเข้า import tensorflow as tf #(tensorflow) C:\Users\Techatach>python
#>>>import tensorflow as tf
#>>>print(tf.__version__)
#>>>quit()

### เข้าไปสู่ tensorflow อีกครั้ง (tensorflow) C:\Users\Techatach>
## conda activate tensorflow ## หรือ activate tensorflow
#python -m ipykernel install --user --name tensorflow --display-name "Python 3.6 (tensorflow)"
#################################
### ใช้คำสั่ง exit ออกจากคำสั่ง (tensorflow) C:\Users\Techatach>exit
### ไปที่ Anaconda Prompt (C:\Users\Techatach>)
#pip install tensorflow
#pip install keras

# %%
##### LabelEncoder & OneHotEncoder #####
##https://towardsdatascience.com/encoding-categorical-features-21a2651a065c

#df = pd.get_dummies(df, columns=['Entity'], prefix=['Entity']).head()

## Categorical boolean mask ##
#categorical_feature_mask = df.dtypes==object
## filter categorical columns using mask and turn it into a list ##
#categorical_cols = df.columns[categorical_feature_mask].tolist()

## import labelencoder ##
#from sklearn.preprocessing import LabelEncoder
## instantiate labelencoder object ##
#le = LabelEncoder()

## apply le on categorical feature columns ##
#df[categorical_cols] = df[categorical_cols].apply(lambda col: le.fit_transform(col))
#df[categorical_cols] #.head(10)
#df

# %%
#import webbrowser
#webbrowser.open('https://gist.github.com/fabsta/b5b667adcc814f226691f239000bfd50')
#s = c.convert_objects(convert_numeric=True)
#c.to_csv('local_data.csv')
#d.to_excel('LEdata.xlsx')
#df = pd.read_excel(r'D:\HDI\HDI_data.xlsx') #, index_col='State')
#b = pd.read_csv('D:/wbdata/cancer2.csv', index_col='Entity', parse_dates=True)
#d = df.loc[df['Year'] == 2017].set_index('Entity') #เลือกเฉพาะปี 2017

# %%
#คำสั่งแสดงแถว คอลัมน์ และลบจุทศนิยม
#pd.set_option('display.max_rows',65) #คำสั่งแสดงแถว 200
#pd.set_option('display.max_columns',65) #คำสั่งแสดงคอลัมน์ 65 คอลัมน์
#pd.set_option('display.float_format','{:,.0f}'.format)
#webbrowser.open('https://gist.github.com/fabsta/b5b667adcc814f226691f239000bfd50') #Learning coding
#t5 = d5[0].drop(['Date','Life expectancy.1','Ch.'], axis=1) #ลบคอลัมน์
#s = s1.drop([77,140,43,119]) #,axis=0) #ลบแถว
#data5 = data5.loc[:, ['Entity','Code','Year','Breast cancer (deaths)']] #เลือกคอลัมน์

# %%
#คำสั่งใช้ลบจุทศนิยม
#t5 = d5[0].drop(['Date','Life expectancy.1','Ch.'], axis=1)
### coding การสร้างกราฟแท่ง
### import seaborn as sns
### import matplotlib.pyplot as plt
### from matplotlib.ticker import FuncFormatter #for custom number format on x and y axis
### %matplotlib inline
### %config InlineBackend.figure_format = 'retina'
### plt.figure(figsize=(7,7))
### ax = sns.barplot(x='2018', y='Country',data=n.sort_values(by='2018', ascending=False).head(15),color='.75');
### การตัดเครื่องหมาย % หรือ $ ออกจากตัวเลขเพื่อนำไปคำนวณ เช่น 1000% 1000$ เป็นต้น
### df['% of GDP']=df['% of GDP'].str.replace(r'%', '').astype('float')
### df['% of GDP']=df['% of GDP'].str.replace('%', '').astype('float')
### การตัดเครื่องหมาย * ออกจากข้อมความ เช่น Thailand*, Thailand[+]
### df.country=df.country.str.replace(r'[^\s+\w]', '')
### df.country=df.country.str.replace('[+]', '')

# %%
from sklearn import datasets
import webbrowser
import pandas as pd
import seaborn as sns

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter #for custom number format on x and y axis
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
import numpy as np
import statsmodels.api as sm
import statsmodels.formula.api as smf
import statsmodels.formula.api as sm

# %%
from pandas import read_csv
import io
import requests
import pandas as pd
from zipfile import ZipFile
from IPython.display import display_html

# %%
print(f'pandas version: {pd.__version__}')
print(f'numpy version: {np.__version__}')
print(f'seaborn version: {sns.__version__}')
# Out:
# pandas version: 0.25.3
# numpy version: 1.17.4
# seaborn version: 0.9.0

# %%
#https://stackoverflow.com/questions/46568913/tensorflow-import-error-no-module-named-tensorflow
###<base> C:\Users\tae>
#conda install matplotlib --force
#conda create -n tensorflow python=3.5
#pip install tensorflow==1.13.1
#pip install tensorflow==1.14.0

###activate tensorflow
#pip install --ignore-installed --upgrade tensorflow
#python -m pip install --upgrade pip

# %%
#pip install tensorflow==1.13.1
#pip install keras
#print(cv2.__version__)
import tensorflow as tf
import keras
print(tf.__version__)
# Out:
# 1.13.1

# %%
#df.to_csv('D:/Python_machine learning/PM25_1/data.csv')
#m = df.loc[df['Country'].isin(['Thailand'])] #,'Myanmar','Vietnam'])] 
#d = df.loc[df['Year'] == 2019] #.rename(columns={'Internet':'y'}) #เลือกเฉพาะปี 2016

# %%
from pandas import read_csv
data1 = pd.read_csv('D:/PM25_1/Chiang_Mai.csv')
data2 = pd.read_csv('D:/PM25_1/Chiang_Rai.csv')
data3 = pd.read_csv('D:/PM25_1/Nakhon_Ratchasima.csv')
data4 = pd.read_csv('D:/PM25_1/Paoy_Paet.csv')
data5 = pd.read_csv('D:/PM25_1/Vientiane.csv')
df = pd.concat([data1, data2, data3, data4, data5])
df = df.reset_index()
df
# Out:
#         index  Year   Month   Day   UTC Hour   PM2.5   PM10_mask  \
# 0           0  2016       3     3          8    53.7           1
# 1           1  2016       3     3          9    53.7           1
# 2           2  2016       3     3         10    53.7           1
# 3           3  2016       3     3         11    53.7           1
# 4           4  2016       3     3         12    33.4           1
# ...       ...   ...     ...   ...        ...     ...         ...
# 136926  21657  2020       1    25         20    60.4           0
# 136927  21658  2020       1    25         22    55.3           0
# 136928  21659  2020       1    26          2    89.7           0
# 136929  21660  2020       1    26          4    68.3           0
# 136930  21661  2020       1    26          6    49.5           0
#
#          Retrospective
# 0                    0
# 1                    0
# 2                    0
# 3                    0
# 4                    0
# ...                ...
# ...

# %%
df = pd.read_csv('D:/PM25_1/China.csv')
df
# Out:
#        Year  Month  Day  UTC Hour   PM25  PM10_mask  Retrospective
# 0      2014      5   16         0  48.32        1.0              1
# 1      2014      5   16         1  47.39        1.0              1
# 2      2014      5   16         2  47.05        1.0              1
# 3      2014      5   16         3  45.72        0.0              1
# 4      2014      5   16         4  51.74        0.0              1
# ...     ...    ...  ...       ...    ...        ...            ...
# 46245  2020      1   25        20  56.79        0.0              0
# 46246  2020      1   25        22  51.38        0.0              0
# 46247  2020      1   26         0  48.68        0.0              0
# 46248  2020      1   26         2  51.70        0.0              0
# 46249  2020      1   26         4  54.25        0.0              0
#
# [46250 rows x 7 columns]

# %%
#import webbrowser
#webbrowser.open('https://machinelearningmastery.com/multivariate-time-series-forecasting-lstms-keras/')

# %%
from math import sqrt
from numpy import concatenate
from matplotlib import pyplot
from pandas import read_csv
from pandas import DataFrame
from pandas import concat
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout

# %%
from pandas import read_csv
from datetime import datetime
# load data
def parse(x):
	return datetime.strptime(x, '%Y %m %d %H')
dataset = pd.read_csv('D:/PM25_1/China.csv',  parse_dates = [['Year', 'Month', 'Day', 'UTC Hour']], index_col=0, date_parser=parse)
#dataset.drop('No', axis=1, inplace=True)
# manually specify column names
dataset.columns = ['PM25', 'PM10_mask', 'Respective']
dataset.index.name = 'date'
# mark all NA values with 0
dataset['PM25'].fillna(0, inplace=True)
# drop the first 24 hours
dataset = dataset[24:].dropna()
# summarize first 5 rows
print(dataset.head(5))
# save to file
#dataset.to_csv('D:/PM25_1/ChinaNew.csv')
# Out:
#                       PM25  PM10_mask  Respective
# date
# 2014-05-17 00:00:00  36.47        0.0           1
# 2014-05-17 01:00:00  36.85        0.0           1
# 2014-05-17 02:00:00  35.91        0.0           1
# 2014-05-17 03:00:00  38.24        0.0           1
# 2014-05-17 04:00:00  40.17        0.0           1

# %%
from pandas import read_csv
from matplotlib import pyplot
# load dataset
df = pd.read_csv('D:/PM25_1/ChinaNew.csv', header=0, index_col=0)
values = df.dropna().values
# specify columns to plot
groups = [0,1,2]
i = 1
# plot each column
pyplot.figure(figsize=(15,5))
for group in groups:
	pyplot.subplot(len(groups), 1, i)
	pyplot.plot(values[:, group])
	pyplot.title(df.columns[group], y=0.5, loc='right')
	i += 1
pyplot.show()

# %%
plt.rcParams['font.family']='Tahoma'
plt.rcParams['font.size']=16
dataset.PM25.resample('D').sum().plot(title='สถานการณ์ฝุ่น PM2.5 จำแนกตามผลรวมรายวัน ตั้งแต่ปี 2015-2020\n', figsize=(12,5)) 
#df.Global_active_power.resample('D').mean().plot(title='Global_active_power resampled over day', color='red') 
plt.tight_layout()
plt.show()   

dataset.PM25.resample('D').mean().plot(title='สถานการณ์ฝุ่น PM2.5 จำแนกตามค่าเฉลี่ยรายวัน ตั้งแต่ปี 2015-2020\n', color='red', figsize=(12,5)) 
plt.tight_layout()
plt.show()

# %%
plt.rcParams['font.family']='Tahoma'
plt.rcParams['font.size']=16
### Below I show mean and std of 'PM25' resampled over day 
r = dataset.PM25.resample('D').agg(['mean', 'std'])
r.plot(subplots = True, title='สถานการณ์ฝุ่น PM2.5 จำแนกตามค่าเฉลี่ยรายวัน ตั้งแต่ปี 2015-2020\n', figsize=(15,5))
plt.show()

# %%
plt.rcParams['font.family']='Tahoma'
plt.rcParams['font.size']=20
ax = dataset[['PM25']].plot(kind='line', 
                          figsize=(14, 6),
                          marker='s', linestyle='-',                                 
                          fontsize=18,
                          color=['green'], 
                          title='\nTrends of Breast cancer (deaths) in Thailand\n')

ax.grid(linestyle='-', linewidth='1', color='blue')
ax.set_title('\nสถานการณ์ฝุ่น PM2.5 ในประเทศจีน\n', 
             fontsize=20, color='green')
ax.set_xlabel('\nสถานการณ์ฝุ่น PM2.5 ตั้งแต่ปี 2015-2020\nค่ามาตรฐานเฉลี่ยราย 24 ชั่วโมง จะต้องไม่เกิน 50 ไมโครกรัมต่อลูกบาศก์เมตร\n', fontsize=16, color='green');
ax.set_ylabel('ไมโครกรัมต่อลูกบาศก์เมตร', fontsize=16, color='green');
#plt.legend()
#plt.show()

##for i in ax.patches:
    # get_width pulls left or right; get_y pushes up or down
    ##ax.text(i.get_width()+.01, i.get_y()+.01, \
            ##str(round((i.get_width()), 2)), fontsize=18, color='blue')

# %%
### Sum of 'Global_active_power' resampled over month
# Sum of 'Global_active_power' resampled over month
plt.rcParams['font.family']='Tahoma'
plt.rcParams['font.size']=11
dataset['PM25'].resample('M').mean().plot(kind='bar', color='green', figsize=(12,5))
plt.xticks(rotation=90)
plt.ylabel('pm25')
plt.title('สถานการณ์ฝุ่น PM2.5 จำแนกตามรายเดือน ตั้งแต่ปี 2016-2020\n')
plt.show()

# %%
## Mean of 'Global_active_power' resampled over quarter
plt.rcParams['font.family']='Tahoma'
plt.rcParams['font.size']=16
dataset['PM25'].resample('Q').mean().plot(kind='bar', color='blue', figsize=(12,5))
plt.xticks(rotation=90)
plt.ylabel('PM25')
plt.title('สถานการณ์ฝุ่น PM2.5 จำแนกตามรายไตรมาส ตั้งแต่ปี 2016-2020\n')
plt.show()

# %%
## Mean of 'Global_active_power' resampled over quarter
plt.rcParams['font.family']='Tahoma'
plt.rcParams['font.size']=16
dataset['PM25'].resample('A').mean().plot(kind='bar', color='blue', figsize=(12,5))
plt.xticks(rotation=90)
plt.ylabel('PM25')
plt.title('สถานการณ์ฝุ่น PM2.5 จำแนกตามรายปี ตั้งแต่ปี 2016-2020\n')
plt.show()

# %%
avg = dataset['PM25'].mean() #.sum()/10
plt.axvline(avg, color='red', linestyle='--') 
plt.rcParams['font.family']='Tahoma'
plt.rcParams['font.size']=16

ax = dataset['PM25'].resample('Q').mean().sort_values(ascending=True).plot(kind='barh',
                          figsize=(8, 9), #width, length
                          linewidth=25,
                          fontsize=18,
                          color=['green','red','black','c']);

ax.set_title('\n\nสถานการณ์ฝุ่น PM2.5 ตั้งแต่ปี 2015-2020\nค่ามาตรฐานเฉลี่ยราย 24 ชั่วโมง จะต้องไม่เกิน 50 ไมโครกรัมต่อลูกบาศก์เมตร\n', 
             fontsize=16, color='blue')
ax.set_xlabel('\nค่าเฉลี่ยไมโครกรัมต่อลูกบาศก์เมตร (----- ค่าเฉลี่ย = 39.13)\n', fontsize=16, color='blue');

# set individual bar lables using above list
for i in ax.patches:
    # get_width pulls left or right; get_y pushes up or down
    ax.text(i.get_width()+.01, i.get_y()+.01, \
            str(round((i.get_width()), 2)), fontsize=18, color='blue')

# invert for largest on top 
#ax.invert_yaxis()

# %%
avg
# Out:
# 39.12777073508406

# %%
#dataset = pd.read_csv('D:/Python_machine learning/PM25/Bangkok2.csv', header=0, index_col=0)

# %%
# convert series to supervised learning
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
	n_vars = 1 if type(data) is list else data.shape[1]
	df = DataFrame(data)
	cols, names = list(), list()
	# input sequence (t-n, ... t-1)
	for i in range(n_in, 0, -1):
		cols.append(df.shift(i))
		names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
	# forecast sequence (t, t+1, ... t+n)
	for i in range(0, n_out):
		cols.append(df.shift(-i))
		if i == 0:
			names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
		else:
			names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
	# put it all together
	agg = concat(cols, axis=1)
	agg.columns = names
	# drop rows with NaN values
	if dropnan:
		agg.dropna(inplace=True)
	return agg

# %%
# load dataset
dataset = pd.read_csv('D:/PM25_1/ChinaNew.csv', header=0, index_col=0)
values = dataset.values
# integer encode direction
encoder = LabelEncoder()
values[:,0] = encoder.fit_transform(values[:,0])
# ensure all data is float
values = values.astype('float32')
# normalize features
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(values)
# frame as supervised learning
reframed = series_to_supervised(scaled, 1, 1)
# drop columns we don't want to predict

reframed.drop(reframed.columns[[4,5]], axis=1, inplace=True)
print(reframed.head())
# Out:
#    var1(t-1)  var2(t-1)  var3(t-1)   var1(t)
# 1   0.345231        0.0        1.0  0.350930
# 2   0.350930        0.0        1.0  0.336833
# 3   0.336833        0.0        1.0  0.371776
# 4   0.371776        0.0        1.0  0.400720
# 5   0.400720        0.0        1.0  0.434613

# %%
# split into train and test sets
values = reframed.values
n_train_hours = 365*24
train = values[:n_train_hours, :]
test = values[n_train_hours:, :]
# split into input and outputs
train_X, train_y = train[:, :-1], train[:, -1]
test_X, test_y = test[:, :-1], test[:, -1]
# reshape input to be 3D [samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (8760, 1, 3) (8760,) (37465, 1, 3) (37465,)

# %%
# design network
model = Sequential()
model.add(LSTM(50, input_shape=(train_X.shape[1], train_X.shape[2])))
#model.add(Dropout(0.3))
model.add(Dense(1))
model.compile(loss='mae', optimizer='adam')
model.summary()
# fit network
history = model.fit(train_X, train_y, epochs=50, batch_size=72, validation_data=(test_X, test_y), verbose=2, shuffle=False)
# plot history
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()
pyplot.show()
# Out:
# Model: "sequential_18"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# lstm_18 (LSTM)               (None, 50)                10800
# _________________________________________________________________
# dense_18 (Dense)             (None, 1)                 51
# ...
# Total params: 10,851
# Trainable params: 10,851
# Non-trainable params: 0
# _________________________________________________________________
# Train on 8760 samples, validate on 37465 samples
# Epoch 1/50
#  - 3s - loss: 0.1538 - val_loss: 0.1381
# Epoch 2/50
#  - 1s - loss: 0.1045 - val_loss: 0.1208
# Epoch 3/50
#  - 1s - loss: 0.0866 - val_loss: 0.1039
# Epoch 4/50
#  - 1s - loss: 0.0689 - val_loss: 0.0853
# Epoch 5/50
#  - 1s - loss: 0.0525 - val_loss: 0.0634
# Epoch 6/50
#  - 1s - loss: 0.0399 - val_loss: 0.0431
# Epoch 7/50
#  - 2s - loss: 0.0324 - val_loss: 0.0356
# Epoch 8/50
#  - 1s - loss: 0.0305 - val_loss: 0.0346
# Epoch 9/50
# ...

# %%
import numpy as np
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
#from sklearn import metrics
# make a prediction
yhat = model.predict(test_X)
test_X = test_X.reshape((test_X.shape[0], test_X.shape[2]))

# %%
# invert scaling for forecast
inv_yhat = concatenate((yhat, test_X[:, 1:]), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat = inv_yhat[:,0]

# %%
# invert scaling for actual
test_y = test_y.reshape((len(test_y), 1))
inv_y = concatenate((test_y, test_X[:, 1:]), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y = inv_y[:,0]

# %%
# calculate RMSE and MAE
import sklearn.metrics as metrics
rmse = sqrt(mean_squared_error(inv_y, inv_yhat))
#print('Test RMSE: %.3f' % rmse)
#print('Test MAE:',metrics.mean_absolute_error(inv_y, inv_yhat))
print('\nR Square using built-in function:', r2_score(inv_y, inv_yhat))
print('Mean Absolute Error:', mean_absolute_error(inv_y, inv_yhat))
print('Root Mean Squared Error:', np.sqrt(mean_squared_error(inv_y, inv_yhat)))
# Out:
# R Square using built-in function: 0.9541151589482482
# Mean Absolute Error: 222.05609
# Root Mean Squared Error: 314.79837

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter #for custom number format on x and y axis
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

## time steps, every step is one hour (you can easily convert the time step to the actual time index)
## for a demonstration purpose, I only compare the predictions in 3000 hours. 

plt.figure(figsize=(15,5))
aa=[x for x in range(8640)] #8640พยากรณ์สถานการณ์ฝุ่น PM2.5 ในช่วง 1 ปี
plt.plot(aa, inv_y[:8640], marker='.', label="actual")
plt.plot(aa, inv_yhat[:8640], 'r', label="prediction")
plt.ylabel('PM25', size=16)
plt.xlabel('Time step', size=15)
plt.legend(fontsize=15)
plt.show()

# %%
df1 = DataFrame(inv_y).rename(columns={0:'actual'}).reset_index()
df2 = DataFrame(inv_yhat).rename(columns={0:'prediction'}).reset_index()
d = pd.merge(df1,df2) #.head(10)
d
# Out:
#        index       actual   prediction
# 0          0  1391.000000  1561.478149
# 1          1  1339.000000  1439.306641
# 2          2  1554.000000  1390.879517
# 3          3  1608.000000  1591.357910
# 4          4  1844.000000  1641.811401
# ...      ...          ...          ...
# 37460  37460  4330.000000  4194.341309
# 37461  37461  3792.000000  3760.975098
# 37462  37462  3522.000244  3315.423096
# 37463  37463  3823.999756  3091.802734
# 37464  37464  4078.000244  3341.928711
#
# [37465 rows x 3 columns]

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter #for custom number format on x and y axis
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

## time steps, every step is one hour (you can easily convert the time step to the actual time index)
## for a demonstration purpose, I only compare the predictions in 3000 hours. 

plt.figure(figsize=(15,5))
#aa.resample('Q').mean()
aa=[x for x in range(17280)] #พยากรณ์สถานการณ์ฝุ่น PM2.5 ในช่วง 2 ปี
plt.plot(aa, inv_y[:17280], marker='.', label="actual")
plt.plot(aa, inv_yhat[:17280], 'r', label="prediction")
plt.ylabel('PM25', size=16)
plt.xlabel('Time step', size=15)
plt.legend(fontsize=15)
plt.show()

# %%
d1 = DataFrame(inv_y).rename(columns={0:'actual'}).reset_index()
d2 = DataFrame(inv_yhat).rename(columns={0:'prediction'}).reset_index()
df = pd.merge(d1,d2)#.head(10)
df
# Out:
#        index       actual   prediction
# 0          0  1391.000000  1557.462769
# 1          1  1339.000000  1435.086060
# 2          2  1554.000000  1386.571655
# 3          3  1608.000000  1587.389404
# 4          4  1844.000000  1637.919189
# ...      ...          ...          ...
# 37460  37460  4330.000000  4236.372559
# 37461  37461  3792.000000  3804.834717
# 37462  37462  3522.000244  3361.380127
# 37463  37463  3823.999756  3138.888428
# 37464  37464  4078.000244  3387.755615
#
# [37465 rows x 3 columns]

# %% [markdown]
# ## สรุป coding การพยากรณ์ฝุ่น PM2.5 ในประเทศจีน

# %%
from math import sqrt
from numpy import concatenate
from matplotlib import pyplot
from pandas import read_csv
from pandas import DataFrame
from pandas import concat
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from sklearn import metrics
import numpy as np
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
 
# convert series to supervised learning
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
	n_vars = 1 if type(data) is list else data.shape[1]
	df = DataFrame(data)
	cols, names = list(), list()
	# input sequence (t-n, ... t-1)
	for i in range(n_in, 0, -1):
		cols.append(df.shift(i))
		names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
	# forecast sequence (t, t+1, ... t+n)
	for i in range(0, n_out):
		cols.append(df.shift(-i))
		if i == 0:
			names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
		else:
			names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
	# put it all together
	agg = concat(cols, axis=1)
	agg.columns = names
	# drop rows with NaN values
	if dropnan:
		agg.dropna(inplace=True)
	return agg
 
# load dataset
dataset = read_csv('D:/PM25_1/ChinaNew.csv', header=0, index_col=0)
values = dataset.values
# integer encode direction
encoder = LabelEncoder()
values[:,0] = encoder.fit_transform(values[:,0])
# ensure all data is float
values = values.astype('float32')
# normalize features
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(values)
# frame as supervised learning
reframed = series_to_supervised(scaled, 1, 1)
# drop columns we don't want to predict
reframed.drop(reframed.columns[[4, 5]], axis=1, inplace=True)
print(reframed.head())
 
# split into train and test sets
values = reframed.values
n_train_hours = 365 * 24
train = values[:n_train_hours, :]
test = values[n_train_hours:, :]
# split into input and outputs
train_X, train_y = train[:, :-1], train[:, -1]
test_X, test_y = test[:, :-1], test[:, -1]
# reshape input to be 3D [samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
 
# design network
model = Sequential()
model.add(LSTM(50, input_shape=(train_X.shape[1], train_X.shape[2])))
model.add(Dense(1))
model.compile(loss='mae', optimizer='adam')
model.summary()
# fit network
history = model.fit(train_X, train_y, epochs=100, batch_size=72, validation_data=(test_X, test_y), verbose=2, shuffle=False)
# plot history
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()
pyplot.show()
 
# make a prediction
yhat = model.predict(test_X)
test_X = test_X.reshape((test_X.shape[0], test_X.shape[2]))
# invert scaling for forecast
inv_yhat = concatenate((yhat, test_X[:, 1:]), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat = inv_yhat[:,0]
# invert scaling for actual
test_y = test_y.reshape((len(test_y), 1))
inv_y = concatenate((test_y, test_X[:, 1:]), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y = inv_y[:,0]
# calculate RMSE
rmse = sqrt(mean_squared_error(inv_y, inv_yhat))
print('Test RMSE: %.3f' % rmse)
#print('Test MAE:',metrics.mean_absolute_error(inv_y, inv_yhat))

print('R Square using built-in function:', r2_score(inv_y, inv_yhat))
print('Mean Absolute Error:', mean_absolute_error(inv_y, inv_yhat))
print('Root Mean Squared Error:', np.sqrt(mean_squared_error(inv_y, inv_yhat)))
# Out:
#    var1(t-1)  var2(t-1)  var3(t-1)   var1(t)
# 1   0.345231        0.0        1.0  0.350930
# 2   0.350930        0.0        1.0  0.336833
# 3   0.336833        0.0        1.0  0.371776
# 4   0.371776        0.0        1.0  0.400720
# 5   0.400720        0.0        1.0  0.434613
# (8760, 1, 3) (8760,) (37465, 1, 3) (37465,)
# Model: "sequential_19"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# lstm_19 (LSTM)               (None, 50)                10800
# _________________________________________________________________
# dense_19 (Dense)             (None, 1)                 51
# ...
# Total params: 10,851
# Trainable params: 10,851
# Non-trainable params: 0
# _________________________________________________________________
# Train on 8760 samples, validate on 37465 samples
# Epoch 1/100
#  - 1s - loss: 0.1439 - val_loss: 0.1350
# Epoch 2/100
#  - 1s - loss: 0.0994 - val_loss: 0.1168
# Epoch 3/100
# ...

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter #for custom number format on x and y axis
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

## time steps, every step is one hour (you can easily convert the time step to the actual time index)
## for a demonstration purpose, I only compare the predictions in 200 hours. 

plt.figure(figsize=(15,5))
aa=[x for x in range(8640)]#พยากรณ์สถานการณ์ฝุ่น PM2.5 ในช่วง 2 ปี
plt.plot(aa, inv_y[:8640], marker='.', label="actual")
plt.plot(aa, inv_yhat[:8640], 'r', label="prediction")
plt.ylabel('PM25', size=15)
plt.xlabel('Time step', size=15)
plt.legend(fontsize=15)
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter #for custom number format on x and y axis
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

## time steps, every step is one hour (you can easily convert the time step to the actual time index)
## for a demonstration purpose, I only compare the predictions in 3000 hours. 

plt.figure(figsize=(15,5))
#aa.resample('Q').mean()
aa=[x for x in range(17280)] #พยากรณ์สถานการณ์ฝุ่น PM2.5 ในช่วง 2 ปี
plt.plot(aa, inv_y[:17280], marker='.', label="actual")
plt.plot(aa, inv_yhat[:17280], 'r', label="prediction")
plt.ylabel('PM25', size=16)
plt.xlabel('Time step', size=15)
plt.legend(fontsize=15)
plt.show()
